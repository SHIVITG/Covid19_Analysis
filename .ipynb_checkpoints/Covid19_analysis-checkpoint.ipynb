# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
covid_data = pd.read_csv("table.tsv", delimiter="\t")

# %%
covid_data.shape
# Out:
# (504, 19)

# %%
covid_data.dtypes
# Out:
# ID                       int64
# Unique id                int64
# Government id           object
# Diagnosed date          object
# Age                    float64
# Gender                  object
# Detected city           object
# Detected city pt        object
# Detected district       object
# Detected state          object
# Nationality             object
# Current status          object
# Status change date      object
# Notes                   object
# Current location       float64
# Current location pt     object
# Created on              object
# Updated on              object
# Contacts                object
# dtype: object

# %%
covid_data.head()
# Out:
#    ID  Unique id Government id Diagnosed date   Age   Gender  \
# 0   1          1      KL-TS-P1    30/Jan/2020  20.0   Female
# 1   2          2      KL-AL-P1    02/Feb/2020   NaN  Unknown
# 2   3          3      KL-KS-P1    03/Feb/2020   NaN  Unknown
# 3   4          4         DL-P1    02/Mar/2020  45.0     Male
# 4   5          5         TS-P1    02/Mar/2020   NaN  Unknown
#
#               Detected city                                Detected city pt  \
# 0                  Thrissur  SRID=4326;POINT (76.21325419999999 10.5256264)
# 1                 Alappuzha   SRID=4326;POINT (76.333482 9.498000100000001)
# 2                 Kasargode                         SRID=4326;POINT (80 20)
# 3  East Delhi (Mayur Vihar)                         SRID=4326;POINT (80 20)
# 4                 Hyderabad   SRID=4326;POINT (78.4349398685041 17.4263524)
#
#   Detected district Detected state Nationality Current status  \
# 0          Thrissur         Kerala       India      Recovered
# ...

# %%
covid_data.columns
# Out:
# Index(['ID', 'Unique id', 'Government id', 'Diagnosed date', 'Age', 'Gender',
#        'Detected city', 'Detected city pt', 'Detected district',
#        'Detected state', 'Nationality', 'Current status', 'Status change date',
#        'Notes', 'Current location', 'Current location pt', 'Created on',
#        'Updated on', 'Contacts'],
#       dtype='object')

# %%
covid_data[:1]
# Out:
#    ID  Unique id Government id Diagnosed date   Age  Gender Detected city  \
# 0   1          1      KL-TS-P1    30/Jan/2020  20.0  Female      Thrissur
#
#                                  Detected city pt Detected district  \
# 0  SRID=4326;POINT (76.21325419999999 10.5256264)          Thrissur
#
#   Detected state Nationality Current status Status change date  \
# 0         Kerala       India      Recovered         02/14/2020
#
#                                        Notes  Current location  \
# 0  Travelled from Wuhan.\nStudent from Wuhan               NaN
#
#                               Current location pt             Created on  \
# 0  SRID=4326;POINT (76.21325419999999 10.5256264)  03/23/2020 12:20 p.m.
#
#               Updated on Contacts
# 0  03/23/2020 12:20 p.m.      NaN

# %%
covid_data['Current status'].describe()
# Out:
# count              503
# unique               3
# top       Hospitalized
# freq               480
# Name: Current status, dtype: object

# %%
covid_data['Gender'].describe()
# Out:
# count         504
# unique          4
# top       Unknown
# freq          210
# Name: Gender, dtype: object

# %%
covid_data['Age'].describe()
# Out:
# count    249.000000
# mean      40.477912
# std       17.799752
# min        2.000000
# 25%       25.000000
# 50%       37.000000
# 75%       55.000000
# max       96.000000
# Name: Age, dtype: float64

# %%
covid_data['Detected state'].describe()
# Out:
# count             504
# unique             23
# top       Maharashtra
# freq               97
# Name: Detected state, dtype: object

# %%
covid_data['Nationality'].describe()
# Out:
# count       349
# unique        8
# top       India
# freq        307
# Name: Nationality, dtype: object

# %%
covid_data['Nationality'].value_counts()
# Out:
# India             307
# Italy              18
# Indonesia          10
# United Kingdom      7
# Thailand            2
# Phillipines         2
# Indian              2
# Canada              1
# Name: Nationality, dtype: int64

# %%
sns.set(font_scale=1.4)
covid_data['Nationality'].value_counts().plot(kind='barh', figsize=(8, 6), edgecolor='black',
                                              color=['lightblue', 'yellow','red', 'green', 'blue', 'cyan']);
plt.ylabel("Nationality of Affected Person", labelpad=14)
plt.xlabel("Count of People", labelpad=14)
plt.title("Nationality & Count of People Affected", y=1.02);

# %%
sns.set(font_scale=1.4)
covid_data['Gender'].value_counts().plot(kind='barh', figsize=(8, 6), edgecolor='black',
                                              color=['lightblue', 'yellow','red', 'green', 'blue', 'cyan']);

plt.ylabel("Gender of Affected People", labelpad=14)
plt.xlabel("Count of People", labelpad=14)
plt.title("Count of Gender of People Affected", y=1.02);

# %%
sns.set(font_scale=1.4)
covid_data['Detected state'].value_counts().plot(kind='barh', figsize=(10, 8), edgecolor='black',
                                              color=(0.1, 0.2, 0.3, 0.4));
plt.ylabel("Covid-19 Dected Cases State", labelpad=14)
plt.xlabel("Count of Cases", labelpad=14)
plt.title("Detected Cases in different state if India", y=1.02);

# %%
covid_data.Age.describe()
# Out:
# count    249.000000
# mean      40.477912
# std       17.799752
# min        2.000000
# 25%       25.000000
# 50%       37.000000
# 75%       55.000000
# max       96.000000
# Name: Age, dtype: float64

# %%
sns.set(font_scale=1.4)
covid_data['Current status'].value_counts().plot(kind='barh', figsize=(8, 6), edgecolor='black',
                                              color=['lightblue', 'yellow','red', 'green', 'blue', 'cyan']);

plt.ylabel("Gender of Affected People", labelpad=14)
plt.xlabel("Count of People", labelpad=14)
plt.title("Count of Gender of People Affected", y=1.02);

# %%
sns.set(font_scale=1.0)
covid_data['Detected district'].value_counts().plot(kind='bar', figsize=(15, 10), edgecolor='black',
                                              color=(0.1, 0.4, 0.8, 1));
plt.ylabel("Covid-19 Dected Cases State", labelpad=14)
plt.xlabel("Count of Cases", labelpad=14)
plt.title("Detected Cases in different district of India", y=1.02);

# %%
sns.set(font_scale=1.0)
covid_data['Diagnosed date'].value_counts().plot(kind='barh', figsize=(15, 10), edgecolor='black',
                                              color=(0.1, 0.4, 0.8, 1));
plt.ylabel("Covid-19 Dected Cases Date", labelpad=14)
plt.xlabel("Count of Cases", labelpad=14)
plt.title("Date of Detected Cases in India", y=1.02);

# %%
covid_data.groupby('Age').count()['Diagnosed date'].plot()
